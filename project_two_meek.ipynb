# %%
# Import dependancies
import os
import requests
import pandas as pd
import json
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
# create variable for api key 
owlracle_API_KEY = os.getenv("owlracle_api_key")

# %%
# Append url for our api
url = "https://owlracle.info/eth/history?candles=1000&timeframe=1d"

# %%
# Read json data from API URL
eth_gas_history = pd.read_json(url, convert_dates = True)

# %%
# Separate gas price columns from json
gas_price_candles = pd.json_normalize(eth_gas_history['gasPrice'])
gas_price_candles
# Out:
#       open  close    low    high
# 0    27.36  13.83   8.00   69.35
# 1    20.19  14.88   5.10   65.78
# 2     7.69  41.12   6.00   83.45
# 3    32.75  21.54  10.36  145.70
# 4    85.00  59.51  22.04  355.00
# ..     ...    ...    ...     ...
# 979  10.00  10.00   0.70   30.00
# 980  10.00   1.00   1.00   22.50
# 981   1.00   1.93   1.00   30.00
# 982   3.00   1.00   0.85   20.00
# 983   1.00   0.20   0.20   25.00
#
# [984 rows x 4 columns]

# %%
# Concat gas_price_candles and eth_gas_history to a new dataframe
gas_prices_df = pd.concat([gas_price_candles, eth_gas_history], axis=1)

# Drop gasPrice Column
gas_prices_df.drop(['gasPrice','samples'], axis=1, inplace=True)

# Set timestamp as index
gas_prices_df = gas_prices_df.set_index("timestamp")

# Add formated date column
gas_prices_df['date'] = gas_prices_df.index.strftime("%Y-%m-%d")

# Set index to date column
gas_prices_df = gas_prices_df.set_index('date')
gas_prices_df
# Out:
#              open  close    low    high        avgGas
# date
# 2022-07-04  27.36  13.83   8.00   69.35  90313.448417
# 2022-07-03  20.19  14.88   5.10   65.78  98196.350563
# 2022-07-02   7.69  41.12   6.00   83.45  91501.283451
# 2022-07-01  32.75  21.54  10.36  145.70  94811.137054
# 2022-06-30  85.00  59.51  22.04  355.00  89419.183382
# ...           ...    ...    ...     ...           ...
# 2019-10-26  10.00  10.00   0.70   30.00  86257.287893
# 2019-10-25  10.00   1.00   1.00   22.50  68881.416953
# 2019-10-24   1.00   1.93   1.00   30.00  80838.205435
# 2019-10-23   3.00   1.00   0.85   20.00  82505.347888
# 2019-10-22   1.00   0.20   0.20   25.00  76896.891914
#
# [984 rows x 5 columns]

# %%
# Writing my gas_prices_df to CSV file
gas_prices_df.to_csv("./eth_gas_prices.csv")

# %%
# Append url for our api
url_2 = "https://owlracle.info/eth/history?timeframe=1d&to=1571634000&from=1483250400"
eth_gas_history_2 = pd.read_json(url_2, convert_dates = True)
gas_price_candles_2 = pd.json_normalize(eth_gas_history['gasPrice'])

# %%
eth_gas_history_2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Concat gas_price_candles and eth_gas_history to a new dataframe
gas_prices_df_2 = pd.concat([gas_price_candles_2, eth_gas_history_2], axis=1)

# Drop gasPrice Column
gas_prices_df_2.drop(['gasPrice','samples'], axis=1, inplace=True)

# Set timestamp as index
gas_prices_df_2 = gas_prices_df_2.set_index("timestamp")

# Add formated date column
gas_prices_df_2['date'] = gas_prices_df_2.index.strftime("%Y-%m-%d")

# Set index to date column
gas_prices_df_2 = gas_prices_df_2.set_index('date')
gas_prices_df_2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [20], in <cell line: 5>()
#       2 gas_prices_df_2 = pd.concat([gas_price_candles_2, eth_gas_history_2], axis=1)
#       4 # Drop gasPrice Column
# ----> 5 gas_prices_df_2.drop(['gasPrice','samples'], axis=1, inplace=True)
#       7 # Set timestamp as index
#       8 gas_prices_df_2 = gas_prices_df_2.set_index("timestamp")
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['gasPrice', 'samples'] not found in axis"
