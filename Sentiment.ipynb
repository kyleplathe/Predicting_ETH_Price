# %%
#Imports
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#Read in the csv file
df = pd.read_csv('/Volumes/5Tb/Test/Project_2/Resources/2017_data.csv', index_col = "date", infer_datetime_format=True, parse_dates=True)

#df = df.drop(columns = ["Column 1", "id", "language"])

#Renaming the dataframe to identify it as a pandas dataframe (when using with Optimus)
df_pd = df
df_pd
# Out:
#             Day of Year                  id  \
# date
# 2017-12-30          364  947255896203255808
# 2017-12-30          364  947255847490551808
# 2017-12-30          364  947255473836785665
# 2017-12-30          364  947255391838142464
# 2017-12-30          364  947255378089332739
# ...                 ...                 ...
# 2017-10-07          280  916749940101070849
# 2017-10-07          280  916749895033290752
# 2017-10-07          280  916749824371904512
# 2017-10-07          280  916749667517517825
# 2017-10-07          280  916749586026434560
#
#                                                         tweet language  \
# date
# 2017-12-30  As EOS Tops $8 Is the Sun About to Set on Ethe...       en
# 2017-12-30  Assume #gdax is down or slow for everyone?  I ...       en
# 2017-12-30  Come #trade #crypto with our team over this ho...       en
# 2017-12-30  Cryptocurrency expert released after $1 millio...       en
# ...

# %%
df_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 302101 entries, 2017-12-30 to 2017-10-07
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Day of Year  302101 non-null  int64
#  1   id           302101 non-null  int64
#  2   tweet        302101 non-null  object
#  3   language     302101 non-null  object
#  4   hashtags     302101 non-null  object
#  5   username     302101 non-null  object
#  6   nlikes       302101 non-null  int64
#  7   nretweets    302101 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 20.7+ MB

# %%
# Download/Update the VADER Lexicon
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/richardmelvin/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#List comprehension to create the table.
df_pd['compound'] = [analyzer.polarity_scores(x)['compound'] for x in df_pd['tweet']]
df_pd['neg'] = [analyzer.polarity_scores(x)['neg'] for x in df_pd['tweet']]
df_pd['neu'] = [analyzer.polarity_scores(x)['neu'] for x in df_pd['tweet']]
df_pd['pos'] = [analyzer.polarity_scores(x)['pos'] for x in df_pd['tweet']]

#Look at the dataframe
df_pd
# Out:
#             Day of Year                  id  \
# date
# 2017-12-30          364  947255896203255808
# 2017-12-30          364  947255847490551808
# 2017-12-30          364  947255473836785665
# 2017-12-30          364  947255391838142464
# 2017-12-30          364  947255378089332739
# ...                 ...                 ...
# 2017-10-07          280  916749940101070849
# 2017-10-07          280  916749895033290752
# 2017-10-07          280  916749824371904512
# 2017-10-07          280  916749667517517825
# 2017-10-07          280  916749586026434560
#
#                                                         tweet language  \
# date
# 2017-12-30  As EOS Tops $8 Is the Sun About to Set on Ethe...       en
# 2017-12-30  Assume #gdax is down or slow for everyone?  I ...       en
# 2017-12-30  Come #trade #crypto with our team over this ho...       en
# 2017-12-30  Cryptocurrency expert released after $1 millio...       en
# ...

# %%
#Save the dataframe
sentiment_2017_df = df_pd
sentiment_2017_df
# Out:
#             Day of Year                  id  \
# date
# 2017-12-30          364  947255896203255808
# 2017-12-30          364  947255847490551808
# 2017-12-30          364  947255473836785665
# 2017-12-30          364  947255391838142464
# 2017-12-30          364  947255378089332739
# ...                 ...                 ...
# 2017-10-07          280  916749940101070849
# 2017-10-07          280  916749895033290752
# 2017-10-07          280  916749824371904512
# 2017-10-07          280  916749667517517825
# 2017-10-07          280  916749586026434560
#
#                                                         tweet language  \
# date
# 2017-12-30  As EOS Tops $8 Is the Sun About to Set on Ethe...       en
# 2017-12-30  Assume #gdax is down or slow for everyone?  I ...       en
# 2017-12-30  Come #trade #crypto with our team over this ho...       en
# 2017-12-30  Cryptocurrency expert released after $1 millio...       en
# ...

# %%
sentiment_2017_df.to_csv('/Volumes/5Tb/Current/Project_2/sentiment_2017.csv')

# %%
eighteen_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1738098 entries, 2018-01-01 to 2018-12-31
# Data columns (total 12 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Day of Year  int64
#  1   id           int64
#  2   tweet        object
#  3   language     object
#  4   hashtags     object
#  5   username     object
#  6   nlikes       float64
#  7   nretweets    float64
#  8   compound     float64
#  9   neg          float64
#  10  neu          float64
#  11  pos          float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 172.4+ MB

# %%
eighteen_df.count()
# Out:
# Day of Year    1738098
# id             1738098
# tweet          1738098
# language       1738092
# hashtags       1738092
# username       1738092
# nlikes         1738092
# nretweets      1738092
# compound       1738098
# neg            1738098
# neu            1738098
# pos            1738098
# dtype: int64

# %%
eighteen_df.to_csv('/Volumes/5Tb/Test/Project_2/Resources/eighteen_df.csv')

# %%
#Save the dataframe
seventeen_df = df_pd

# %%
seventeen_df
# Out:
#             Day of Year                  id  \
# date
# 2017-10-07          280  916890263766945792
# 2017-10-07          280  916890188575522816
# 2017-10-07          280  916890185035481089
# 2017-10-07          280  916889803416891393
# 2017-10-07          280  916889723255250944
# ...                 ...                 ...
# 2017-12-30          364  946984201554821120
# 2017-12-30          364  946984201378820096
# 2017-12-30          364  946984198979637248
# 2017-12-30          364  946984196941271040
# 2017-12-30          364  946984195628437506
#
#                                                         tweet language  \
# date
# 2017-10-07  'SmartNET' The Worlds Low Power Wide Area Netw...       en
# 2017-10-07  Recent Ethereum Upgrade May Make Wall Street F...       en
# 2017-10-07  Recent Ethereum Upgrade May Make Wall Street F...       en
# 2017-10-07  Bitcoin Hard Fork Segwit2x Closing-In: Coinbas...       en
# ...

# %%
seventeen_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 302101 entries, 2017-10-07 to 2017-12-30
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Day of Year  302101 non-null  int64
#  1   id           302101 non-null  int64
#  2   tweet        302101 non-null  object
#  3   language     302101 non-null  object
#  4   hashtags     302101 non-null  object
#  5   username     302101 non-null  object
#  6   nlikes       302101 non-null  int64
#  7   nretweets    302101 non-null  int64
#  8   compound     302101 non-null  float64
#  9   neg          302101 non-null  float64
#  10  neu          302101 non-null  float64
#  11  pos          302101 non-null  float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 30.0+ MB

# %%
seventeen_df.count()
# Out:
# Day of Year    302101
# id             302101
# tweet          302101
# language       302101
# hashtags       302101
# username       302101
# nlikes         302101
# nretweets      302101
# compound       302101
# neg            302101
# neu            302101
# pos            302101
# dtype: int64

# %%
seventeen_df.to_csv('/Volumes/5Tb/Test/Project_2/Resources/seventeen.csv')

# %%
eighteen = eighteen_df.groupby('date').mean()

# %%
eighteen
# Out:
#             Day of Year            id    nlikes  nretweets  compound  \
# date
# 2018-01-01          1.0  9.480580e+17  2.301105   4.505525  0.169366
# 2018-01-02          2.0  9.482184e+17  3.668230   2.602071  0.141499
# 2018-01-04          4.0  9.491424e+17  0.820037   2.189239  0.143665
# 2018-01-05          5.0  9.492885e+17  2.249867   1.588277  0.149442
# 2018-01-07          7.0  9.502331e+17  4.511719   1.708984  0.167536
# ...                 ...           ...       ...        ...       ...
# 2018-12-27        361.0  1.078338e+18  2.797257   2.516696  0.144919
# 2018-12-28        362.0  1.078711e+18  5.206354   1.269309  0.156838
# 2018-12-29        363.0  1.079062e+18  3.943403   0.889583  0.195421
# 2018-12-30        364.0  1.079427e+18  1.808467   0.454080  0.180362
# 2018-12-31        365.0  1.079754e+18  2.541616   1.064555  0.239490
#
#                  neg       neu       pos
# date
# 2018-01-01  0.020691  0.902293  0.077014
# 2018-01-02  0.025547  0.900448  0.074004
# ...
