# %%
# !pip install hvplot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 3.1 MB 18.7 MB/s
# ...

# %%
# Import dependencies
import numpy as np
import pandas as pd
import hvplot.pandas
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Upload CSV file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-00063aab-3908-43f5-a385-166763b26fe0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-00063aab-3908-43f5-a385-166763b26fe0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ETH-USD.csv to ETH-USD.csv

# %%
# Read data 
eth_df = pd.read_csv('ETH-USD.csv', index_col="Date", infer_datetime_format=True, parse_dates=True)
eth_df = eth_df.drop(['Adj Close'], axis=1)
eth_df
# Out:
#                    Open         High          Low        Close       Volume
# Date
# 2017-11-09   308.644989   329.451996   307.056000   320.884003    893249984
# 2017-11-10   320.670990   324.717987   294.541992   299.252991    885985984
# 2017-11-11   298.585999   319.453003   298.191986   314.681000    842300992
# 2017-11-12   314.690002   319.153015   298.513000   307.907990   1613479936
# 2017-11-13   307.024994   328.415009   307.024994   316.716003   1041889984
# ...                 ...          ...          ...          ...          ...
# 2022-03-21  2860.103271  2954.556641  2838.250488  2897.976563  15206116098
# 2022-03-22  2897.774170  3040.382813  2892.544434  2973.131104  16830539230
# 2022-03-23  2973.145020  3036.752197  2933.306641  3031.067139  16008767658
# 2022-03-24  3031.060791  3118.387695  3012.326660  3108.062012  18070503166
# 2022-03-25  3109.523438  3182.826660  3097.624268  3122.535889  16882068480
#
# [1598 rows x 5 columns]

# %%
# Upload CSV file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a733b47f-4ff5-48f5-a98e-351062954963" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a733b47f-4ff5-48f5-a98e-351062954963">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving PersonalSavings1.csv to PersonalSavings1.csv

# %%
# Read data
Personal_Savings_df = pd.read_csv('PersonalSavings1.csv', index_col="Date", infer_datetime_format=True, parse_dates=True)
Personal_Savings_df = Personal_Savings_df.rename(columns={"PSAVERT": "Personal Saving %"})
Personal_Savings_df
# Out:
#             Personal Saving %
# Date
# 2014-07-01                7.2
# 2014-08-01                7.0
# 2014-09-01                7.2
# 2014-10-01                7.1
# 2014-11-01                7.3
# ...                       ...
# 2021-12-01                8.7
# 2022-01-01                6.0
# 2022-02-01                5.9
# 2022-03-01                5.0
# 2022-04-01                4.4
#
# [94 rows x 1 columns]

# %%
# Fill in the missing data days of the month
Personal_Daily_Savings = Personal_Savings_df.resample("D").ffill()
Personal_Daily_Savings.head()
# Out:
#             Personal Saving %
# Date
# 2014-07-01                7.2
# 2014-07-02                7.2
# 2014-07-03                7.2
# 2014-07-04                7.2
# 2014-07-05                7.2

# %%
# Export CSV file
from google.colab import files

Personal_Daily_Savings.to_csv('Personal Savings.csv', encoding = 'utf-8-sig') 
files.download('Personal Savings.csv')

# %%
# Upload CSV file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-996c0e6f-2362-4821-af99-522cf1860032" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-996c0e6f-2362-4821-af99-522cf1860032">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving S&P500_index_5yrs.csv to S&P500_index_5yrs.csv

# %%
sp_index_df = pd.read_csv('S&P500_index_5yrs.csv', index_col="Date", infer_datetime_format=True, parse_dates=True)
sp_index_df = sp_index_df.drop(['Open', 'High', 'Low', 'Volume'], axis=1)
sp_index_df = sp_index_df.sort_index(ascending=True)
sp_index_df
# Out:
#             Close/Last
# Date
# 2017-06-28     2440.69
# 2017-06-29     2419.70
# 2017-06-30     2423.41
# 2017-07-03     2429.01
# 2017-07-05     2432.54
# ...                ...
# 2022-06-21     3764.79
# 2022-06-22     3759.89
# 2022-06-23     3795.73
# 2022-06-24     3911.74
# 2022-06-27     3900.11
#
# [1258 rows x 1 columns]

# %%
# Concatenate all the dataframes into one
eth_all_features_df = pd.concat([eth_df, Personal_Daily_Savings, sp_index_df], join="inner", axis=1,)
eth_all_features_df
# Out:
#                    Open         High          Low        Close       Volume  \
# Date
# 2017-11-09   308.644989   329.451996   307.056000   320.884003    893249984
# 2017-11-10   320.670990   324.717987   294.541992   299.252991    885985984
# 2017-11-13   307.024994   328.415009   307.024994   316.716003   1041889984
# 2017-11-14   316.763000   340.177002   316.763000   337.631012   1069680000
# 2017-11-15   337.963989   340.911987   329.812988   333.356995    722665984
# ...                 ...          ...          ...          ...          ...
# 2022-03-21  2860.103271  2954.556641  2838.250488  2897.976563  15206116098
# 2022-03-22  2897.774170  3040.382813  2892.544434  2973.131104  16830539230
# 2022-03-23  2973.145020  3036.752197  2933.306641  3031.067139  16008767658
# 2022-03-24  3031.060791  3118.387695  3012.326660  3108.062012  18070503166
# 2022-03-25  3109.523438  3182.826660  3097.624268  3122.535889  16882068480
#
#             Personal Saving %  Close/Last
# Date
# ...

# %%
from google.colab import files

eth_all_features_df.to_csv('eth_features.csv', encoding = 'utf-8-sig') 
files.download('eth_features.csv')

# %%
import holoviews as hv
hv.extension('bokeh')

eth_all_features_df.hvplot()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
